# %%
import torch
import numpy as np
from TD3 import TD3
import time
import rospy
from utils import ReplayBuffer,MultiStepMemory,PER
from PER import Memory
from std_msgs.msg import Float32MultiArray
import sys
import os
# from Env.environment_stage_2 import Env
import numpy as np
log_interval = 5           # print avg reward after interval
gamma = 0.99                # discount for future rewards
batch_size = 256            # num of transitions sampled from replay buffer
lr = 5e-4
exploration_noise =0.8
polyak = 0.995              # target policy update parameter (1-tau)
policy_noise = 1.0         # target policy smoothing noise
noise_clip = 0.5
policy_delay = 2            # delayed policy updates parameter
max_episodes = 600         # max num of episodes
max_timesteps = 500        # max timesteps in one episode
pretrain_times = 0
warmup_epoch = 0
state_dim = 64
action_dim = 2
max_action = 1.0

# %%
class importDataset(object):
    def __init__(self, state_dim, action_dim):
        self.datasetPath = "/home/cmq/ljn/RL/turtlebot3/src/dqn-navigation/turtlebot3_machine_learning/turtlebot3_machine_learning/scripts/dataset_cali.npy"
        self.dataset = np.load(self.datasetPath, allow_pickle=True)
        self.state_dim = state_dim
        self.action_dim = action_dim

    def transfer(self):
        self.buffer = []
        for data in self.dataset:
            state = data[0]
            action = data[1]
            reward = data[2]
            next_state = data[3]
            finish = float(data[4])
            assert len(state) == state_dim
            assert(len(action)) == action_dim
            assert len(next_state) == state_dim
            self.buffer.append((state, action, reward, next_state, finish))
        return self.buffer
policy = TD3(lr, state_dim, action_dim, max_action)
replay_buffer = ReplayBuffer()
replay_buffer.importDataset(importDataset(state_dim,action_dim).transfer())
# Out:
# IMPORT DATASET WITH LENGTH:10001

# %%
def calculate_loss():
    loss_fn = torch.nn.MSELoss(reduction='sum')
    sample = replay_buffer.sample(128,1)
    action = policy.batch_inference(sample[0])
    action = torch.FloatTensor(action).reshape(-1,2)
    print(action[1])
    gt = torch.FloatTensor(sample[1])
    loss = loss_fn(action, gt)
    print(loss/action.size(0))
calculate_loss()
# Out:
# tensor([ 0.2630, -0.9620])
# tensor(2.6311)

# %%
    pretrain_times = 100
    for i in range(pretrain_times):
        if(i % 10 == 0):
            print("finish batch :%d", i)
            calculate_loss()
        policy.update(replay_buffer, 500, batch_size, gamma,
                      polyak, policy_noise, noise_clip, policy_delay, 1)
# Out:
# ('finish batch :%d', 0)
# tensor([ 0.2794, -0.7397])
# tensor(2.2937)
# tensor([[ 3.5000,  0.5928,  0.4773,  ...,  1.2700,  0.4700,  4.0000],
#         [ 1.6500,  1.5112,  1.3970,  ...,  1.7400,  1.0400, 12.0000],
#         [ 0.4839,  0.4818,  0.4465,  ...,  3.4600,  0.3700, 11.0000],
#         ...,
#         [ 1.3943,  1.3625,  1.3604,  ...,  2.5700,  0.2100,  6.0000],
#         [ 1.1954,  0.9505,  0.8190,  ...,  1.7000,  0.4500,  8.0000],
#         [ 1.6077,  1.6051,  1.5976,  ...,  0.4000,  0.5300, 23.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  0.4972,  0.4941,  ...,  1.2400,  0.4900,  2.0000],
#         [ 1.7707,  1.6123,  1.4560,  ...,  1.7100,  1.0200, 11.0000],
#         [ 0.4604,  0.4218,  0.4008,  ...,  3.4300,  0.3700,  5.0000],
#         ...,
#         [ 1.4584,  1.4225,  1.3934,  ...,  2.5500,  0.2300,  6.0000],
#         [ 0.6879,  0.5874,  0.5259,  ...,  1.6700,  0.4700,  4.0000],
#         [ 1.6017,  1.6021,  1.6275,  ...,  0.3700,  0.4900, 19.0000]],
#        device='cuda:0')
# tensor([[ 1.7342,  1.8084,  1.8728,  ...,  0.1300,  0.5100, 32.0000],
#         [ 0.4304,  0.4303,  0.4748,  ...,  0.2500,  0.4300,  1.0000],
#         [ 3.0948,  3.5000,  3.5000,  ...,  1.5600,  0.6700, 44.0000],
#         ...,
#         [ 0.5492,  0.5411,  0.5448,  ...,  1.2500,  0.5400,  3.0000],
#         [ 1.2126,  1.2183,  1.2175,  ...,  2.1900,  0.4100, 21.0000],
#         [ 1.8922,  2.0711,  1.9650,  ...,  3.0700,  0.6900, 20.0000]],
#        device='cuda:0')
# tensor([[ 2.0957,  2.2385,  2.3767,  ...,  0.9500,  0.4200, 30.0000],
#         [ 0.6181,  0.7019,  0.7561,  ...,  0.2000,  0.6200,  0.0000],
#         [ 0.6574,  3.0293,  3.5000,  ...,  1.5500,  0.6600,  0.0000],
#         ...,
#         [ 0.6189,  0.5923,  0.5806,  ...,  1.1800,  0.5700,  3.0000],
#         [ 1.2617,  1.2321,  1.2674,  ...,  2.1600,  0.3700, 18.0000],
#         [ 1.8093,  1.9028,  2.0664,  ...,  2.9900,  0.6300, 20.0000]],
#        device='cuda:0')
# tensor([[ 0.9776,  0.7993,  0.6888,  ...,  2.9500,  0.5800,  4.0000],
#         [ 3.2441,  3.5000,  3.5000,  ...,  1.7400,  0.4000, 10.0000],
#         [ 0.3721,  0.3451,  0.3532,  ...,  0.5400,  0.2800,  7.0000],
#         ...,
#         [ 2.2225,  2.3255,  2.4195,  ...,  2.8300,  0.8000, 15.0000],
#         [ 0.6239,  0.5478,  0.5076,  ...,  0.8000,  0.3300, 11.0000],
#         [ 1.0080,  1.0014,  0.9918,  ...,  1.0500,  0.8100, 26.0000]],
#        device='cuda:0')
# tensor([[ 3.3835,  1.4043,  1.0824,  ...,  2.9200,  0.6200,  6.0000],
#         [ 1.4208,  1.5091,  1.6180,  ...,  1.7000,  0.4000, 11.0000],
#         [ 0.3809,  0.3663,  0.3540,  ...,  0.5000,  0.2900,  6.0000],
#         ...,
#         [ 2.2430,  2.3099,  2.3779,  ...,  2.8000,  0.7900, 17.0000],
#         [ 0.7217,  0.6371,  0.5351,  ...,  0.7600,  0.3200, 13.0000],
#         [ 1.0545,  1.0298,  1.0209,  ...,  1.0200,  0.7400, 25.0000]],
#        device='cuda:0')
# tensor([[ 3.2225,  3.3196,  3.4684,  ...,  3.7200,  0.8500, 39.0000],
#         [ 1.9168,  2.0946,  2.3300,  ...,  3.8000,  0.7500, 29.0000],
#         [ 2.6908,  2.7007,  2.7724,  ...,  2.3000,  1.2000, 27.0000],
#         ...,
#         [ 0.6761,  0.6353,  0.5762,  ...,  3.1300,  0.4800,  6.0000],
#         [ 1.5449,  1.4331,  1.2899,  ...,  1.8800,  0.9400, 13.0000],
#         [ 3.5000,  3.5000,  2.4403,  ...,  4.5100,  0.7100, 48.0000]],
#        device='cuda:0')
# tensor([[ 3.0664,  3.1081,  3.1324,  ...,  3.6800,  0.8400, 43.0000],
#         [ 2.5206,  2.4314,  2.3500,  ...,  3.7600,  0.6700, 26.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  2.3000,  0.5600, 58.0000],
#         ...,
#         [ 1.2074,  1.0158,  0.8534,  ...,  3.0700,  0.5200, 10.0000],
#         [ 1.5231,  1.3762,  1.2517,  ...,  1.8000,  0.9400, 10.0000],
#         [ 3.2646,  3.2342,  0.8666,  ...,  4.5000,  0.7500, 44.0000]],
#        device='cuda:0')
# tensor([[ 1.0922,  1.2262,  1.3671,  ...,  3.3900,  0.9500, 59.0000],
#         [ 1.0252,  1.0950,  1.1962,  ...,  4.1200,  0.9700, 52.0000],
#         [ 0.8868,  0.8903,  3.2362,  ...,  3.6200,  0.7000, 38.0000],
#         ...,
#         [ 0.9870,  0.7734,  0.6228,  ...,  0.9400,  0.2600, 16.0000],
#         [ 1.3863,  1.3353,  1.3072,  ...,  2.1100,  0.9500, 25.0000],
#         [ 3.5000,  3.0395,  2.4612,  ...,  0.5800,  0.9800, 17.0000]],
#        device='cuda:0')
# tensor([[ 1.4398,  1.6492,  1.9476,  ...,  3.3600,  0.9300, 59.0000],
#         [ 0.9093,  0.9553,  1.0205,  ...,  4.0800,  0.9100,  0.0000],
#         [ 2.0344,  1.9598,  2.1248,  ...,  3.5400,  0.6200, 31.0000],
#         ...,
#         [ 0.4320,  0.3853,  0.3628,  ...,  0.9400,  0.2300, 12.0000],
#         [ 1.3381,  1.3018,  2.3573,  ...,  2.1100,  0.9100, 23.0000],
#         [ 3.5000,  2.9361,  2.3921,  ...,  0.5200,  0.9400, 17.0000]],
#        device='cuda:0')
# tensor([[ 1.6093,  1.5461,  1.4965,  ...,  3.4700,  0.5900, 17.0000],
#         [ 0.6929,  0.6198,  0.5583,  ...,  0.4200,  0.4200, 13.0000],
#         [ 3.1115,  3.3877,  3.4066,  ...,  2.4400,  0.4500, 15.0000],
#         ...,
#         [ 2.0943,  1.9552,  1.8379,  ...,  3.0500,  0.4700,  8.0000],
#         [ 1.5108,  1.4516,  1.4240,  ...,  2.9900,  0.8900, 50.0000],
#         [ 0.7769,  3.5000,  2.5593,  ...,  3.1600,  0.7800,  0.0000]],
#        device='cuda:0')
# tensor([[ 1.5055,  1.5038,  1.4541,  ...,  3.4000,  0.5900, 14.0000],
#         [ 0.5999,  0.5725,  0.5532,  ...,  0.4000,  0.4300,  9.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  2.4000,  0.4300, 18.0000],
#         ...,
#         [ 1.9365,  0.5616,  0.5474,  ...,  3.0100,  0.4700, 10.0000],
#         [ 1.1545,  1.2657,  1.3763,  ...,  2.9100,  0.8900, 55.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  3.1600,  0.8100, 14.0000]],
#        device='cuda:0')
# tensor([[ 2.1720,  1.9901,  1.8812,  ...,  2.3400,  0.3500, 10.0000],
#         [ 1.3602,  1.3700,  1.3780,  ...,  6.5100,  0.7300, 14.0000],
#         [ 2.6487,  2.9629,  2.9308,  ...,  3.8500,  0.6800,  8.0000],
#         ...,
#         [ 0.4508,  0.3819,  0.3962,  ...,  1.1200,  0.3800,  1.0000],
#         [ 0.6071,  0.5743,  0.5783,  ...,  1.3700,  0.5700,  1.0000],
#         [ 0.6678,  0.8236,  1.3687,  ...,  2.5300,  0.6700,  0.0000]],
#        device='cuda:0')
# tensor([[ 2.5274,  2.2860,  2.0848,  ...,  2.3000,  0.3700, 11.0000],
#         [ 1.3952,  1.3966,  1.4294,  ...,  6.4800,  0.7400, 12.0000],
#         [ 2.9732,  1.1138,  0.7927,  ...,  3.8300,  0.6900,  3.0000],
#         ...,
#         [ 0.4341,  0.4602,  0.4843,  ...,  1.0900,  0.4300,  0.0000],
#         [ 0.6358,  0.6246,  0.6183,  ...,  1.3400,  0.6200,  2.0000],
#         [ 2.9674,  2.9992,  3.0343,  ...,  2.4900,  0.9700, 42.0000]],
#        device='cuda:0')
# tensor([[ 2.9804,  2.8821,  2.7594,  ...,  3.0300,  0.2400, 13.0000],
#         [ 1.8869,  1.9812,  2.0632,  ...,  4.1500,  0.5500, 16.0000],
#         [ 2.4150,  2.4373,  2.4995,  ...,  4.5500,  0.6100, 15.0000],
#         ...,
#         [ 2.5123,  1.4967,  1.4931,  ...,  4.9800,  0.8500, 20.0000],
#         [ 3.5000,  2.0203,  2.0515,  ...,  1.7400,  0.3200,  9.0000],
#         [ 1.6106,  1.5900,  1.5880,  ...,  1.9600,  0.5500, 10.0000]],
#        device='cuda:0')
# tensor([[ 3.2538,  3.3523,  3.1411,  ...,  2.9600,  0.2300, 11.0000],
#         [ 2.1109,  2.2184,  2.3775,  ...,  4.1200,  0.5100, 13.0000],
#         [ 2.4134,  2.4313,  2.4525,  ...,  4.4900,  0.5600, 17.0000],
#         ...,
#         [ 2.4768,  2.5097,  2.5546,  ...,  4.9400,  0.8300, 16.0000],
#         [ 3.5000,  2.0727,  2.0872,  ...,  1.6900,  0.3300,  8.0000],
#         [ 1.6908,  1.6646,  1.6598,  ...,  1.9500,  0.5800, 11.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.5000,  ...,  0.8200,  0.2900, 12.0000],
#         [ 2.5710,  2.6857,  2.7818,  ...,  2.2400,  0.4000, 13.0000],
#         [ 0.8218,  0.7605,  0.7508,  ...,  0.5900,  0.4200, 48.0000],
#         ...,
#         [ 2.0690,  0.6395,  0.6286,  ...,  3.4600,  0.4100, 43.0000],
#         [ 2.1799,  2.2584,  2.3339,  ...,  4.0100,  0.5300, 14.0000],
#         [ 2.1411,  2.1677,  2.1969,  ...,  3.9000,  0.5800, 11.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  2.6559,  3.1778,  ...,  0.7900,  0.3000, 13.0000],
#         [ 2.6609,  2.7978,  2.9278,  ...,  2.1700,  0.3900, 12.0000],
#         [ 2.9836,  1.0067,  0.9312,  ...,  0.5400,  0.4200, 52.0000],
#         ...,
#         [ 2.7178,  2.4895,  2.3036,  ...,  3.4400,  0.3900, 46.0000],
#         [ 2.6843,  0.7242,  0.6854,  ...,  3.9800,  0.5100, 11.0000],
#         [ 2.5455,  0.6690,  0.6105,  ...,  3.8100,  0.5900,  3.0000]],
#        device='cuda:0')
# tensor([[ 2.7682,  2.8696,  2.9969,  ...,  2.0000,  0.7500,  9.0000],
#         [ 0.8964,  0.9103,  0.9135,  ...,  1.4500,  0.6400, 18.0000],
#         [ 2.8199,  3.0435,  3.2947,  ...,  0.4900,  0.7500, 12.0000],
#         ...,
#         [ 3.5000,  1.2281,  0.9927,  ...,  1.7500,  0.5500,  7.0000],
#         [ 2.4215,  2.2342,  2.0940,  ...,  3.0700,  0.5300, 10.0000],
#         [ 0.4085,  0.4038,  0.4033,  ...,  3.9300,  0.3800,  4.0000]],
#        device='cuda:0')
# tensor([[ 0.8315,  0.9932,  1.2598,  ...,  1.9400,  0.8300,  0.0000],
#         [ 0.9502,  0.9504,  1.0004,  ...,  1.4500,  0.6000, 18.0000],
#         [ 2.3106,  2.4182,  2.9691,  ...,  0.4400,  0.7400,  6.0000],
#         ...,
#         [ 3.5000,  3.5000,  2.9147,  ...,  1.7100,  0.5600, 10.0000],
#         [ 2.3719,  2.5187,  2.3473,  ...,  2.9800,  0.5200, 44.0000],
#         [ 0.4740,  0.4531,  0.4385,  ...,  3.8600,  0.4100,  6.0000]],
#        device='cuda:0')
# tensor([[ 0.3717,  0.3767,  0.4245,  ...,  0.1600,  0.3700,  0.0000],
#         [ 0.3867,  0.4326,  0.4088,  ...,  0.1800,  0.3900,  0.0000],
#         [ 2.4324,  0.6578,  0.6116,  ...,  1.2300,  0.4400, 12.0000],
#         ...,
#         [ 0.7995,  0.8048,  0.7980,  ...,  1.8300,  0.6800, 18.0000],
#         [ 2.6506,  2.8742,  3.0997,  ...,  3.6300,  0.4900, 14.0000],
#         [ 0.5456,  0.5345,  0.5377,  ...,  0.2600,  0.5300,  1.0000]],
#        device='cuda:0')
# tensor([[ 0.6550,  0.7832,  0.8881,  ...,  0.1400,  0.6600,  0.0000],
#         [ 0.4391,  0.4424,  0.4592,  ...,  0.2100,  0.4400,  0.0000],
#         [ 2.6459,  2.7700,  2.5979,  ...,  1.2000,  0.4400, 12.0000],
#         ...,
#         [ 0.8498,  0.8808,  0.8991,  ...,  1.8000,  0.6400, 18.0000],
#         [ 2.5345,  2.6625,  2.8483,  ...,  3.6200,  0.4500, 13.0000],
#         [ 0.6129,  0.6333,  0.6584,  ...,  0.2400,  0.6100, 30.0000]],
#        device='cuda:0')
# tensor([[ 0.6925,  0.6772,  0.6660,  ...,  0.2800,  0.5000, 46.0000],
#         [ 1.1730,  1.2174,  1.2696,  ...,  0.5400,  0.3000, 19.0000],
#         [ 1.8712,  1.7589,  0.8613,  ...,  4.9400,  0.8600,  2.0000],
#         ...,
#         [ 2.2937,  1.1324,  1.0965,  ...,  4.0100,  0.5500, 22.0000],
#         [ 1.2062,  1.2484,  1.2738,  ...,  1.7100,  0.4100, 15.0000],
#         [ 0.8177,  0.9255,  1.0481,  ...,  3.2900,  0.4800, 22.0000]],
#        device='cuda:0')
# tensor([[ 0.6564,  0.6732,  0.6552,  ...,  0.2700,  0.4800, 43.0000],
#         [ 1.2683,  1.2982,  1.3887,  ...,  0.5300,  0.2800, 15.0000],
#         [ 2.0328,  2.0964,  2.1965,  ...,  4.9100,  1.0500, 15.0000],
#         ...,
#         [ 2.0585,  2.0421,  2.0685,  ...,  4.0100,  0.5400, 20.0000],
#         [ 1.2616,  1.3016,  1.3434,  ...,  1.6600,  0.3800, 14.0000],
#         [ 2.1518,  3.0383,  3.5000,  ...,  3.2600,  0.4400, 16.0000]],
#        device='cuda:0')
# tensor([[ 2.4303,  2.6496,  2.8891,  ...,  3.0700,  0.2500, 22.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  1.6500,  0.6100, 21.0000],
#         [ 2.4586,  2.4810,  2.5385,  ...,  3.7200,  0.3500, 12.0000],
#         ...,
#         [ 2.5997,  2.6079,  1.5560,  ...,  2.9300,  0.5900, 12.0000],
#         [ 3.3283,  3.3896,  3.4848,  ...,  1.1200,  0.2700, 35.0000],
#         [ 2.2897,  2.3291,  2.3753,  ...,  2.5800,  0.4100, 17.0000]],
#        device='cuda:0')
# tensor([[ 2.7943,  2.6792,  2.5913,  ...,  3.0600,  0.2500, 18.0000],
#         [ 1.0704,  0.9402,  0.8377,  ...,  1.5500,  0.5500, 10.0000],
#         [ 2.5012,  2.4637,  2.4879,  ...,  3.6500,  0.3600, 14.0000],
#         ...,
#         [ 2.6604,  2.6665,  1.5974,  ...,  2.9100,  0.5900, 13.0000],
#         [ 3.5000,  3.5000,  2.0806,  ...,  1.0700,  0.2300, 33.0000],
#         [ 2.4559,  2.5275,  2.6213,  ...,  2.5400,  0.3700, 14.0000]],
#        device='cuda:0')
# tensor([[ 2.4024,  2.5353,  2.6906,  ...,  1.8900,  0.5500, 16.0000],
#         [ 1.8819,  1.6868,  1.5122,  ...,  2.6500,  0.9900, 13.0000],
#         [ 1.8224,  1.8302,  1.8485,  ...,  0.7800,  0.8900, 19.0000],
#         ...,
#         [ 1.1929,  1.2259,  1.2843,  ...,  4.8300,  0.5000, 26.0000],
#         [ 0.5299,  0.5649,  0.6355,  ...,  0.2200,  0.5300,  0.0000],
#         [ 1.1477,  1.0832,  1.0214,  ...,  0.6800,  0.8600,  9.0000]],
#        device='cuda:0')
# tensor([[ 2.2733,  2.3348,  2.4582,  ...,  1.8400,  0.5100, 17.0000],
#         [ 3.5000,  2.9271,  2.4056,  ...,  2.6500,  0.9900, 15.0000],
#         [ 1.9841,  2.0167,  2.0940,  ...,  0.7600,  0.8500, 15.0000],
#         ...,
#         [ 1.3501,  1.4002,  1.4771,  ...,  4.7700,  0.4500, 23.0000],
#         [ 0.8307,  0.9615,  1.1334,  ...,  0.2000,  0.8300,  0.0000],
#         [ 1.1400,  1.0784,  1.0327,  ...,  0.6200,  0.8800, 10.0000]],
#        device='cuda:0')
# tensor([[ 0.7347,  0.6960,  0.6549,  ...,  2.6800,  0.4900, 11.0000],
#         [ 0.9299,  0.8436,  0.7543,  ...,  0.5400,  0.5100, 11.0000],
#         [ 3.4098,  3.5000,  0.5949,  ...,  1.5500,  0.3900,  3.0000],
#         ...,
#         [ 1.4854,  1.3561,  1.2730,  ...,  3.4100,  0.9200, 12.0000],
#         [ 0.8147,  0.8373,  3.5000,  ...,  2.5400,  0.8100,  0.0000],
#         [ 1.1788,  1.1507,  1.1335,  ...,  3.2200,  0.7600, 21.0000]],
#        device='cuda:0')
# tensor([[ 2.8776,  2.8672,  0.8353,  ...,  2.6500,  0.4900, 15.0000],
#         [ 1.1702,  1.0147,  0.8938,  ...,  0.5100,  0.4900, 15.0000],
#         [ 3.5000,  0.5349,  0.4197,  ...,  1.4700,  0.4200,  2.0000],
#         ...,
#         [ 1.0659,  1.0035,  0.9670,  ...,  3.3800,  0.8900,  7.0000],
#         [ 3.0792,  1.1865,  0.8300,  ...,  2.4800,  0.8300,  3.0000],
#         [ 1.1867,  1.1873,  1.2039,  ...,  3.2000,  0.7100, 19.0000]],
#        device='cuda:0')
# tensor([[ 2.1678,  2.2267,  2.2953,  ...,  2.8900,  0.8400, 17.0000],
#         [ 0.5890,  0.5544,  0.5319,  ...,  1.6300,  0.4900, 48.0000],
#         [ 1.0252,  1.0950,  1.1962,  ...,  4.1200,  0.9700, 52.0000],
#         ...,
#         [ 0.8686,  1.2476,  3.1347,  ...,  3.6200,  0.8300, 48.0000],
#         [ 1.4202,  1.3089,  1.2254,  ...,  1.5200,  0.9700,  9.0000],
#         [ 0.6166,  0.6584,  0.7138,  ...,  0.3100,  0.6200,  0.0000]],
#        device='cuda:0')
# tensor([[ 2.2225,  2.3255,  2.4195,  ...,  2.8300,  0.8000, 15.0000],
#         [ 0.5640,  0.5476,  0.5248,  ...,  1.5900,  0.5100, 47.0000],
#         [ 0.9093,  0.9553,  1.0205,  ...,  4.0800,  0.9100,  0.0000],
#         ...,
#         [ 3.1377,  3.1555,  3.2086,  ...,  3.6100,  0.8100, 44.0000],
#         [ 1.5060,  1.3741,  1.2789,  ...,  1.4900,  0.9600, 10.0000],
#         [ 0.8767,  0.9852,  1.1237,  ...,  0.3300,  0.6500, 59.0000]],
#        device='cuda:0')
# tensor([[ 1.8799,  1.6132,  1.3903,  ...,  1.2600,  0.7600, 15.0000],
#         [ 0.6237,  0.5978,  0.5786,  ...,  2.9200,  0.4800, 38.0000],
#         [ 0.9615,  0.9289,  0.9068,  ...,  0.3400,  0.7400, 51.0000],
#         ...,
#         [ 0.9081,  0.8901,  0.8683,  ...,  0.8200,  0.5500, 28.0000],
#         [ 0.5821,  0.5293,  0.5126,  ...,  0.2100,  0.3500, 10.0000],
#         [ 2.5304,  2.4602,  2.3761,  ...,  5.4100,  0.5500, 13.0000]],
#        device='cuda:0')
# tensor([[ 3.0595,  2.3389,  1.8877,  ...,  1.2200,  0.7500, 15.0000],
#         [ 2.1200,  1.9900,  1.8807,  ...,  2.9100,  0.4700, 42.0000],
#         [ 0.9239,  0.9181,  0.9205,  ...,  0.3100,  0.7200, 49.0000],
#         ...,
#         [ 0.9049,  0.9022,  0.8867,  ...,  0.7900,  0.4900, 24.0000],
#         [ 0.7913,  0.6751,  0.5805,  ...,  0.1300,  0.3500, 14.0000],
#         [ 2.5846,  2.4939,  2.4091,  ...,  5.4100,  0.5700, 13.0000]],
#        device='cuda:0')
# tensor([[ 1.5000,  1.5147,  1.5335,  ...,  1.4300,  0.6600, 57.0000],
#         [ 1.2289,  1.1517,  1.0604,  ...,  0.8400,  0.6400, 35.0000],
#         [ 2.8114,  2.3923,  2.1074,  ...,  0.1900,  0.5800, 36.0000],
#         ...,
#         [ 0.4691,  0.4430,  0.4201,  ...,  4.8600,  0.3500,  7.0000],
#         [ 0.6243,  2.4398,  2.1714,  ...,  1.3200,  0.6200,  0.0000],
#         [ 0.3700,  0.3542,  0.3237,  ...,  0.7800,  0.2600, 13.0000]],
#        device='cuda:0')
# tensor([[ 1.6639,  1.6212,  1.5717,  ...,  1.3900,  0.6900, 13.0000],
#         [ 1.2771,  1.1856,  1.1037,  ...,  0.7800,  0.6000, 36.0000],
#         [ 1.5950,  1.4762,  1.3775,  ...,  0.2000,  0.5400, 30.0000],
#         ...,
#         [ 0.3694,  0.3694,  0.3698,  ...,  4.8700,  0.3400,  6.0000],
#         [ 2.4863,  2.2173,  1.9794,  ...,  1.3500,  1.1100, 45.0000],
#         [ 0.3391,  0.3191,  0.2987,  ...,  0.7400,  0.2600,  7.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.5000,  ...,  1.4300,  0.5800, 13.0000],
#         [ 0.7861,  0.6684,  0.5789,  ...,  1.8700,  0.3100, 15.0000],
#         [ 0.5658,  0.5875,  0.5924,  ...,  1.8600,  0.5000, 28.0000],
#         ...,
#         [ 2.4284,  2.0573,  1.8038,  ...,  1.5000,  0.9700, 15.0000],
#         [ 3.3829,  3.2230,  0.5338,  ...,  0.9200,  0.3300,  6.0000],
#         [ 0.7136,  0.6693,  0.6294,  ...,  2.0300,  0.5400, 10.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.5000,  ...,  1.4100,  0.5500, 16.0000],
#         [ 0.8035,  0.6863,  0.6026,  ...,  1.7900,  0.3100, 16.0000],
#         [ 0.6499,  0.6645,  0.6898,  ...,  1.8400,  0.4600, 25.0000],
#         ...,
#         [ 2.6209,  2.1937,  1.8566,  ...,  1.4500,  0.9400, 16.0000],
#         [ 3.0561,  3.2830,  3.5000,  ...,  0.8500,  0.3500,  8.0000],
#         [ 3.0331,  0.9272,  0.8365,  ...,  2.0000,  0.5500, 13.0000]],
#        device='cuda:0')
# tensor([[ 0.7915,  0.7089,  0.6537,  ...,  1.2100,  0.4300, 11.0000],
#         [ 0.7528,  0.7432,  0.7652,  ...,  0.7900,  0.7400,  1.0000],
#         [ 2.2537,  2.2599,  2.3047,  ...,  2.8200,  0.9000, 18.0000],
#         ...,
#         [ 3.0089,  3.3136,  3.2246,  ...,  3.1700,  0.4300, 13.0000],
#         [ 2.7762,  2.9672,  2.9478,  ...,  4.9500,  0.6600,  8.0000],
#         [ 0.7022,  0.7085,  0.7006,  ...,  1.3600,  0.7000,  2.0000]],
#        device='cuda:0')
# tensor([[ 0.6084,  0.5619,  0.5188,  ...,  1.1900,  0.4300,  6.0000],
#         [ 0.8302,  0.8149,  0.8000,  ...,  0.7100,  0.7800,  3.0000],
#         [ 2.3748,  2.4384,  2.5295,  ...,  2.7600,  0.8800, 16.0000],
#         ...,
#         [ 3.1279,  1.9052,  2.2098,  ...,  3.1400,  0.4200, 10.0000],
#         [ 3.5000,  3.4071,  2.1431,  ...,  4.9400,  0.6900, 11.0000],
#         [ 0.7362,  0.7355,  0.7433,  ...,  1.3000,  0.6900, 19.0000]],
#        device='cuda:0')
# tensor([[ 2.4993,  2.5850,  3.4889,  ...,  0.3400,  1.0300, 26.0000],
#         [ 3.3145,  2.7000,  2.2825,  ...,  2.2700,  1.1000, 16.0000],
#         [ 3.1970,  3.4430,  3.5000,  ...,  3.4100,  0.6000,  8.0000],
#         ...,
#         [ 3.3894,  3.4290,  3.4668,  ...,  0.1100,  0.8100, 19.0000],
#         [ 2.5421,  2.6056,  2.6981,  ...,  1.2300,  0.2500, 11.0000],
#         [ 2.3626,  2.4200,  2.5324,  ...,  3.1400,  0.7600, 55.0000]],
#        device='cuda:0')
# tensor([[ 3.4415,  3.4546,  3.5000,  ...,  0.3000,  0.7700, 58.0000],
#         [ 1.4009,  1.3099,  1.2398,  ...,  2.2200,  1.0600,  8.0000],
#         [ 2.7447,  2.8913,  3.0314,  ...,  3.4100,  0.5900, 10.0000],
#         ...,
#         [ 3.4178,  3.4156,  3.4340,  ...,  2.6100,  0.7600, 21.0000],
#         [ 2.5000,  2.5400,  2.5757,  ...,  1.1800,  0.2800, 10.0000],
#         [ 2.5422,  2.6758,  2.8060,  ...,  3.1400,  0.7900, 54.0000]],
#        device='cuda:0')
# tensor([[ 0.4886,  0.4831,  0.4706,  ...,  0.2500,  0.4200,  9.0000],
#         [ 0.6195,  0.5774,  0.5673,  ...,  4.7100,  0.4600,  8.0000],
#         [ 2.5743,  2.6394,  2.6998,  ...,  1.4700,  0.3700, 14.0000],
#         ...,
#         [ 1.6483,  1.6758,  1.7243,  ...,  0.6600,  0.6500, 47.0000],
#         [ 0.9218,  0.7489,  0.6167,  ...,  3.0600,  0.3800,  7.0000],
#         [ 0.7040,  0.6541,  0.6039,  ...,  0.2700,  0.4300, 13.0000]],
#        device='cuda:0')
# tensor([[ 0.4418,  0.4359,  0.4332,  ...,  0.2400,  0.4200,  4.0000],
#         [ 2.4515,  2.6140,  0.7151,  ...,  4.6700,  0.4800, 12.0000],
#         [ 0.8752,  0.7315,  0.6346,  ...,  1.4300,  0.3500, 16.0000],
#         ...,
#         [ 1.7158,  1.7099,  1.7590,  ...,  0.6200,  0.6500, 49.0000],
#         [ 2.5766,  2.5953,  2.5929,  ...,  3.0200,  0.4000, 10.0000],
#         [ 1.1097,  0.9537,  0.8291,  ...,  0.2400,  0.4200, 14.0000]],
#        device='cuda:0')
# tensor([[ 2.0638,  2.2016,  2.0619,  ...,  1.9900,  0.7100, 17.0000],
#         [ 2.9542,  3.0647,  3.1852,  ...,  2.7900,  1.0900, 36.0000],
#         [ 2.1883,  2.0826,  1.9989,  ...,  0.8800,  0.5500,  9.0000],
#         ...,
#         [ 1.2499,  0.9155,  0.7208,  ...,  7.0100,  0.4000,  8.0000],
#         [ 3.0737,  2.9610,  2.8488,  ...,  2.6900,  0.9300, 13.0000],
#         [ 2.7028,  2.8293,  2.9925,  ...,  1.7900,  0.5000, 12.0000]],
#        device='cuda:0')
# tensor([[ 1.9985,  2.1403,  2.2014,  ...,  1.9200,  0.6500, 17.0000],
#         [ 3.3949,  3.5000,  3.2714,  ...,  2.7200,  1.0100, 33.0000],
#         [ 2.0861,  1.9977,  1.9646,  ...,  0.8200,  0.5500,  8.0000],
#         ...,
#         [ 0.5157,  0.4660,  0.4043,  ...,  6.9400,  0.3900,  3.0000],
#         [ 2.8443,  2.7524,  2.6976,  ...,  2.6500,  0.9300, 10.0000],
#         [ 2.4642,  2.5070,  2.5778,  ...,  1.7100,  0.4900, 15.0000]],
#        device='cuda:0')
# tensor([[ 2.2750,  2.1434,  3.2502,  ...,  0.6600,  0.5800, 11.0000],
#         [ 3.5000,  3.5000,  2.1841,  ...,  0.2300,  0.5200, 21.0000],
#         [ 2.5316,  2.5136,  2.5086,  ...,  1.6900,  0.3800, 13.0000],
#         ...,
#         [ 3.4442,  3.3851,  2.5611,  ...,  0.3500,  0.7900, 17.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  2.8800,  0.4600, 55.0000],
#         [ 1.1897,  1.3195,  1.4391,  ...,  4.6200,  0.6900, 25.0000]],
#        device='cuda:0')
# tensor([[ 2.1847,  3.2729,  3.1562,  ...,  0.6300,  0.5700,  9.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  0.2300,  0.5000, 14.0000],
#         [ 1.7293,  1.6807,  1.9420,  ...,  1.6600,  0.3600, 16.0000],
#         ...,
#         [ 3.5000,  2.7778,  2.1797,  ...,  0.2900,  0.7600, 18.0000],
#         [ 2.3343,  2.4273,  2.5039,  ...,  2.8800,  0.4600, 53.0000],
#         [ 1.3918,  1.3237,  1.2936,  ...,  4.5900,  0.6400, 21.0000]],
#        device='cuda:0')
# tensor([[ 0.7653,  0.6632,  0.5610,  ...,  2.1400,  0.4000,  7.0000],
#         [ 1.0293,  0.9087,  0.8053,  ...,  2.3800,  0.4500, 12.0000],
#         [ 0.5438,  0.5721,  0.5749,  ...,  2.3600,  0.5400,  0.0000],
#         ...,
#         [ 2.5817,  2.8709,  3.1640,  ...,  3.6200,  0.6400, 19.0000],
#         [ 2.3831,  2.6400,  2.9614,  ...,  5.4700,  0.5100,  8.0000],
#         [ 2.0469,  2.0495,  2.0726,  ...,  3.0800,  0.3800, 23.0000]],
#        device='cuda:0')
# tensor([[ 1.1358,  0.9086,  0.7405,  ...,  2.1700,  0.3900,  7.0000],
#         [ 0.8847,  0.7873,  0.7037,  ...,  2.3400,  0.4300, 11.0000],
#         [ 3.5000,  2.3677,  3.5000,  ...,  2.3300,  0.7600, 20.0000],
#         ...,
#         [ 3.0086,  2.9176,  1.7669,  ...,  3.6100,  0.6000, 16.0000],
#         [ 1.9933,  2.1299,  2.2951,  ...,  5.3900,  0.5200, 12.0000],
#         [ 1.2618,  1.1628,  1.1997,  ...,  3.0200,  0.3300, 19.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.2556,  ...,  3.3400,  0.5100, 10.0000],
#         [ 0.5368,  0.5398,  0.5136,  ...,  0.5400,  0.4800,  7.0000],
#         [ 3.5000,  3.5000,  2.9784,  ...,  1.6100,  0.4600, 14.0000],
#         ...,
#         [ 1.1245,  2.1423,  2.1702,  ...,  4.7000,  0.9400, 19.0000],
#         [ 0.8525,  0.9274,  0.9760,  ...,  2.7400,  0.7500, 17.0000],
#         [ 1.9472,  1.8494,  1.7769,  ...,  3.0000,  0.5900, 36.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.5000,  ...,  3.3300,  0.5200, 10.0000],
#         [ 2.6002,  2.4846,  0.6280,  ...,  0.4800,  0.5000,  7.0000],
#         [ 1.8246,  1.8880,  3.5000,  ...,  1.5800,  0.4300, 16.0000],
#         ...,
#         [ 2.2519,  2.2950,  2.4038,  ...,  4.6400,  0.9000, 16.0000],
#         [ 0.8933,  0.9501,  1.0368,  ...,  2.7000,  0.7000, 17.0000],
#         [ 2.3323,  2.4702,  2.5022,  ...,  2.9800,  0.5500, 43.0000]],
#        device='cuda:0')
# tensor([[ 2.8703,  3.1796,  3.5000,  ...,  6.2600,  0.8600,  8.0000],
#         [ 3.5000,  2.1684,  3.5000,  ...,  0.6300,  0.4600, 11.0000],
#         [ 3.3777,  3.5000,  3.5000,  ...,  0.3000,  0.3400, 10.0000],
#         ...,
#         [ 1.7363,  1.6379,  1.6007,  ...,  4.6900,  0.4700,  8.0000],
#         [ 2.1412,  2.0557,  1.9451,  ...,  2.7100,  0.6200, 37.0000],
#         [ 3.5000,  1.6657,  1.5232,  ...,  1.0000,  0.4800, 59.0000]],
#        device='cuda:0')
# tensor([[ 3.1899,  3.5000,  3.5000,  ...,  6.2000,  0.8700,  7.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  0.6100,  0.4800, 13.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  0.2300,  0.3500,  9.0000],
#         ...,
#         [ 1.6622,  1.6042,  1.5679,  ...,  4.6200,  0.4900,  7.0000],
#         [ 2.2053,  2.3311,  2.5106,  ...,  2.6700,  0.6000, 44.0000],
#         [ 2.4689,  2.6964,  3.5000,  ...,  0.9800,  0.6800, 59.0000]],
#        device='cuda:0')
# tensor([[ 1.6047,  2.5432,  2.5426,  ...,  3.8400,  0.7300, 17.0000],
#         [ 1.2499,  0.9155,  0.7208,  ...,  7.0100,  0.4000,  8.0000],
#         [ 1.1697,  1.2086,  1.2403,  ...,  0.7700,  0.6800, 52.0000],
#         ...,
#         [ 0.8242,  0.8112,  0.7941,  ...,  0.1500,  0.2900, 26.0000],
#         [ 2.4158,  2.3166,  2.2492,  ...,  1.9800,  0.7700, 26.0000],
#         [ 2.2937,  1.1324,  1.0965,  ...,  4.0100,  0.5500, 22.0000]],
#        device='cuda:0')
# tensor([[ 2.5835,  2.5711,  2.5752,  ...,  3.8000,  0.6900, 16.0000],
#         [ 0.5157,  0.4660,  0.4043,  ...,  6.9400,  0.3900,  3.0000],
#         [ 1.2433,  1.3179,  1.1977,  ...,  0.7200,  0.7100, 51.0000],
#         ...,
#         [ 0.8052,  0.8053,  0.8250,  ...,  0.1300,  0.2500, 23.0000],
#         [ 2.2935,  0.8751,  0.8564,  ...,  1.9600,  0.7300, 24.0000],
#         [ 2.0585,  2.0421,  2.0685,  ...,  4.0100,  0.5400, 20.0000]],
#        device='cuda:0')
# tensor([[ 0.2604,  0.2737,  0.2745,  ...,  0.1400,  0.2600,  0.0000],
#         [ 0.9426,  0.9066,  0.9281,  ...,  3.2100,  0.7000, 23.0000],
#         [ 2.5888,  1.4472,  1.4332,  ...,  3.8000,  0.2100, 11.0000],
#         ...,
#         [ 0.4336,  0.4003,  0.3940,  ...,  0.1600,  0.3700,  3.0000],
#         [ 0.5997,  0.6095,  0.6197,  ...,  2.0900,  0.6000,  0.0000],
#         [ 0.9357,  0.8380,  0.7602,  ...,  0.2200,  0.5000, 12.0000]],
#        device='cuda:0')
# tensor([[ 0.3104,  0.3137,  0.2969,  ...,  6.0000,  0.3000,  2.0000],
#         [ 0.9398,  0.9327,  0.9158,  ...,  3.2100,  0.6900, 23.0000],
#         [ 1.4485,  1.4211,  1.4627,  ...,  3.8000,  0.2100, 13.0000],
#         ...,
#         [ 0.3867,  0.4326,  0.4088,  ...,  0.1800,  0.3900,  0.0000],
#         [ 0.8742,  0.9613,  1.0494,  ...,  2.1000,  0.6700, 17.0000],
#         [ 1.0259,  0.9260,  0.8015,  ...,  0.2400,  0.4900, 13.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  2.3471,  ...,  1.1500,  0.5500, 16.0000],
#         [ 0.6020,  0.5257,  0.4733,  ...,  1.3400,  0.2800, 11.0000],
#         [ 1.8979,  1.8425,  1.7898,  ...,  1.1100,  0.4600, 10.0000],
#         ...,
#         [ 3.3543,  3.4042,  1.3954,  ...,  1.3300,  0.6800,  9.0000],
#         [ 2.7121,  2.6933,  2.6818,  ...,  2.2300,  0.5700, 12.0000],
#         [ 2.6452,  2.7799,  2.6641,  ...,  3.3500,  0.7800, 24.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.0991,  ...,  1.1500,  0.5400, 14.0000],
#         [ 0.8797,  0.7001,  0.5966,  ...,  1.2600,  0.2900, 12.0000],
#         [ 1.9569,  1.8832,  1.8248,  ...,  1.0800,  0.4700,  9.0000],
#         ...,
#         [ 1.0565,  0.9335,  0.8354,  ...,  1.3400,  0.7000,  4.0000],
#         [ 2.7609,  2.7264,  2.7183,  ...,  2.1500,  0.5600, 11.0000],
#         [ 2.5232,  1.4598,  1.5138,  ...,  3.2500,  0.6900, 13.0000]],
#        device='cuda:0')
# tensor([[ 1.8481,  1.8522,  1.8512,  ...,  1.9100,  0.4200, 51.0000],
#         [ 1.6055,  1.4320,  1.2921,  ...,  1.0600,  0.8800, 13.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  1.1500,  0.4500, 55.0000],
#         ...,
#         [ 1.1249,  1.1626,  1.2091,  ...,  4.3900,  0.6600, 14.0000],
#         [ 1.6368,  1.6721,  1.7149,  ...,  1.3300,  0.5000,  7.0000],
#         [ 1.4882,  1.3401,  1.2602,  ...,  0.7800,  0.8700, 11.0000]],
#        device='cuda:0')
# tensor([[ 1.8739,  0.8106,  0.6741,  ...,  1.9100,  0.4400, 47.0000],
#         [ 3.4680,  2.6724,  2.1650,  ...,  1.0500,  0.8700, 16.0000],
#         [ 2.3478,  2.4318,  2.5803,  ...,  1.1500,  0.4600, 50.0000],
#         ...,
#         [ 1.1808,  1.0301,  0.9508,  ...,  4.3600,  0.6200, 10.0000],
#         [ 1.8066,  0.5320,  0.5291,  ...,  1.3100,  0.5100,  6.0000],
#         [ 1.1607,  1.0784,  1.0063,  ...,  0.7200,  0.8600,  8.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  2.9346,  2.4078,  ...,  0.5500,  0.9800, 17.0000],
#         [ 0.7398,  0.7087,  0.7289,  ...,  1.9400,  0.6700, 58.0000],
#         [ 3.5000,  1.9489,  2.6050,  ...,  0.9400,  0.7200, 25.0000],
#         ...,
#         [ 3.5000,  2.2162,  2.2961,  ...,  3.8200,  0.3900, 50.0000],
#         [ 0.5569,  0.5322,  0.5374,  ...,  0.5800,  0.5300,  1.0000],
#         [ 1.1113,  1.3322,  1.5070,  ...,  3.5400,  0.7100, 45.0000]],
#        device='cuda:0')
# tensor([[ 3.0005,  2.4355,  2.0493,  ...,  0.5300,  0.9600, 16.0000],
#         [ 2.2261,  2.1298,  0.7848,  ...,  1.8900,  0.7400,  6.0000],
#         [ 3.5000,  3.5000,  2.4760,  ...,  0.9200,  0.4700, 59.0000],
#         ...,
#         [ 3.5000,  3.5000,  3.5000,  ...,  3.8000,  0.4100, 55.0000],
#         [ 0.5838,  0.5921,  0.5930,  ...,  0.5100,  0.5800,  4.0000],
#         [ 1.0061,  1.1582,  1.3335,  ...,  3.4600,  0.6900, 47.0000]],
#        device='cuda:0')
# tensor([[ 2.1524,  0.5959,  0.5633,  ...,  1.1500,  0.4400, 10.0000],
#         [ 3.5000,  3.5000,  2.4895,  ...,  1.7300,  0.4300, 25.0000],
#         [ 0.5485,  1.6097,  1.6176,  ...,  2.3000,  0.5500,  0.0000],
#         ...,
#         [ 0.5498,  0.5893,  0.6298,  ...,  4.5100,  0.5500,  0.0000],
#         [ 1.9243,  1.9325,  0.8118,  ...,  1.8800,  0.4300, 51.0000],
#         [ 2.3481,  2.4771,  2.5159,  ...,  2.9700,  0.5400, 44.0000]],
#        device='cuda:0')
# tensor([[ 0.6058,  0.5528,  0.5307,  ...,  1.1700,  0.4300,  9.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  1.6700,  0.3900, 26.0000],
#         [ 0.6393,  0.6019,  0.5952,  ...,  2.2700,  0.6000,  2.0000],
#         ...,
#         [ 0.5491,  0.5643,  0.5974,  ...,  4.4800,  0.5400, 43.0000],
#         [ 1.9790,  1.9223,  1.9496,  ...,  1.8900,  0.4100, 54.0000],
#         [ 3.5000,  2.2229,  2.1446,  ...,  2.9700,  0.5300, 48.0000]],
#        device='cuda:0')
# tensor([[ 3.0683,  3.1410,  3.2426,  ...,  1.0500,  0.5900, 40.0000],
#         [ 2.8017,  2.7132,  2.6854,  ...,  2.2700,  0.3100,  7.0000],
#         [ 0.8302,  0.8149,  0.8000,  ...,  0.7100,  0.7800,  3.0000],
#         ...,
#         [ 0.9120,  0.7837,  0.6935,  ...,  0.5700,  0.3700, 16.0000],
#         [ 0.4905,  0.4827,  0.4888,  ...,  1.2100,  0.4800,  1.0000],
#         [ 2.5500,  2.5848,  2.6375,  ...,  2.3900,  0.4000, 11.0000]],
#        device='cuda:0')
# tensor([[ 1.5037,  1.3507,  1.2295,  ...,  1.0500,  0.5800, 36.0000],
#         [ 2.7374,  2.6911,  2.6764,  ...,  2.2000,  0.3200,  7.0000],
#         [ 0.9376,  0.8957,  0.8622,  ...,  0.6800,  0.8100,  5.0000],
#         ...,
#         [ 0.5896,  0.5410,  0.5019,  ...,  0.5400,  0.3600, 13.0000],
#         [ 0.5489,  0.5729,  0.5963,  ...,  1.2000,  0.5200, 38.0000],
#         [ 2.6433,  2.5975,  2.6153,  ...,  2.3500,  0.4200, 13.0000]],
#        device='cuda:0')
# tensor([[ 1.3168,  1.3075,  1.3160,  ...,  2.7100,  0.5200, 15.0000],
#         [ 0.6518,  0.6968,  0.7360,  ...,  0.2400,  0.6500,  0.0000],
#         [ 0.9892,  0.9368,  0.9190,  ...,  5.4300,  0.8500,  5.0000],
#         ...,
#         [ 0.4520,  0.4485,  0.4367,  ...,  1.0000,  0.4200,  4.0000],
#         [ 2.5720,  2.6261,  2.7233,  ...,  2.2000,  0.4200, 15.0000],
#         [ 2.1416,  2.0823,  2.0435,  ...,  0.2200,  0.3300, 17.0000]],
#        device='cuda:0')
# tensor([[ 1.3211,  1.3331,  1.3369,  ...,  2.6800,  0.5200, 13.0000],
#         [ 1.0360,  1.2031,  1.2501,  ...,  0.2100,  1.0000, 47.0000],
#         [ 3.3224,  1.1295,  1.0542,  ...,  5.3600,  0.8700,  9.0000],
#         ...,
#         [ 0.5081,  0.4871,  0.4732,  ...,  1.0300,  0.4500,  4.0000],
#         [ 2.6098,  2.7084,  2.8142,  ...,  2.1800,  0.3900, 14.0000],
#         [ 2.4114,  2.3103,  2.2041,  ...,  0.1400,  0.3200, 17.0000]],
#        device='cuda:0')
# tensor([[ 0.8577,  0.9268,  1.0390,  ...,  3.9700,  0.8000, 51.0000],
#         [ 3.5000,  2.8560,  2.6137,  ...,  3.5100,  0.6500, 12.0000],
#         [ 0.3742,  0.3817,  0.3811,  ...,  0.5300,  0.3700,  3.0000],
#         ...,
#         [ 0.4760,  0.5262,  3.5000,  ...,  0.3500,  0.4800,  0.0000],
#         [ 3.3855,  1.2872,  1.0263,  ...,  3.2100,  0.6000,  6.0000],
#         [ 2.3753,  2.2001,  2.0546,  ...,  3.6700,  0.4900, 10.0000]],
#        device='cuda:0')
# tensor([[ 0.8854,  0.9541,  1.0685,  ...,  3.9300,  0.7700, 52.0000],
#         [ 3.5000,  2.7675,  2.5436,  ...,  3.5200,  0.6400, 12.0000],
#         [ 0.4256,  0.4189,  3.3055,  ...,  0.4900,  0.4200,  1.0000],
#         ...,
#         [ 0.5096,  0.5214,  0.5299,  ...,  0.3200,  0.5100,  0.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  3.2000,  0.6500, 10.0000],
#         [ 1.8487,  1.7663,  1.7275,  ...,  3.6700,  0.4900,  6.0000]],
#        device='cuda:0')
# tensor([[ 0.7986,  0.7185,  0.6636,  ...,  2.6400,  0.4600, 12.0000],
#         [ 1.8494,  1.8729,  1.9326,  ...,  5.7400,  0.4800, 15.0000],
#         [ 0.4100,  0.4114,  0.4107,  ...,  2.3500,  0.4100,  3.0000],
#         ...,
#         [ 0.4117,  0.4141,  0.3817,  ...,  2.0100,  0.3200,  9.0000],
#         [ 2.6926,  2.7066,  2.6850,  ...,  3.0700,  0.7000, 13.0000],
#         [ 2.0362,  2.0486,  2.0622,  ...,  4.7700,  0.4800,  9.0000]],
#        device='cuda:0')
# tensor([[ 2.9413,  3.0587,  0.8732,  ...,  2.5600,  0.4500, 14.0000],
#         [ 1.8663,  1.9014,  1.9375,  ...,  5.7200,  0.4500, 16.0000],
#         [ 0.4466,  0.4408,  0.4409,  ...,  2.3000,  0.4300,  3.0000],
#         ...,
#         [ 0.4644,  0.4539,  0.4254,  ...,  1.9800,  0.3300, 11.0000],
#         [ 2.7215,  1.6866,  1.7069,  ...,  3.0000,  0.6500, 35.0000],
#         [ 2.0887,  2.1025,  2.1605,  ...,  4.7400,  0.4800,  6.0000]],
#        device='cuda:0')
# tensor([[ 0.9486,  0.8894,  0.7320,  ...,  1.8900,  0.2900, 18.0000],
#         [ 1.3789,  1.4112,  3.5000,  ...,  2.1100,  0.2700, 38.0000],
#         [ 0.6852,  0.7104,  0.7236,  ...,  6.1700,  0.4100, 19.0000],
#         ...,
#         [ 2.2093,  2.2640,  2.3589,  ...,  4.8300,  0.3600, 14.0000],
#         [ 0.7484,  0.6940,  0.6332,  ...,  3.8000,  0.4800, 12.0000],
#         [ 0.6102,  0.6157,  0.6137,  ...,  1.2900,  0.6100,  0.0000]],
#        device='cuda:0')
# tensor([[ 0.8412,  0.7127,  0.5905,  ...,  1.9100,  0.2600, 15.0000],
#         [ 1.9633,  1.7073,  1.5127,  ...,  2.0900,  0.2400, 40.0000],
#         [ 0.7542,  0.7854,  0.7635,  ...,  6.1400,  0.3700, 13.0000],
#         ...,
#         [ 2.1398,  2.1533,  2.1937,  ...,  4.8000,  0.3400, 22.0000],
#         [ 0.6527,  0.6046,  0.5346,  ...,  3.7600,  0.4700,  7.0000],
#         [ 0.6902,  0.6904,  0.6761,  ...,  1.2100,  0.5500, 39.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.5000,  ...,  0.5100,  1.0700, 22.0000],
#         [ 0.5089,  0.4869,  0.4775,  ...,  1.7600,  0.4400,  4.0000],
#         [ 2.3123,  3.4381,  3.2797,  ...,  0.4300,  0.5800,  9.0000],
#         ...,
#         [ 0.4984,  1.4693,  1.4527,  ...,  0.2500,  0.5000,  0.0000],
#         [ 2.9234,  2.9138,  0.5871,  ...,  0.2100,  0.5900,  2.0000],
#         [ 0.8461,  0.7334,  0.6392,  ...,  3.2400,  0.5700,  3.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.5000,  ...,  0.4300,  1.0100, 25.0000],
#         [ 2.7073,  0.6531,  0.6112,  ...,  1.7200,  0.4500, 10.0000],
#         [ 3.2884,  3.1761,  3.0862,  ...,  0.3900,  0.5700,  6.0000],
#         ...,
#         [ 1.5074,  1.5269,  1.5335,  ...,  0.2100,  0.8500, 20.0000],
#         [ 0.6879,  0.6818,  3.1045,  ...,  0.1200,  0.6800,  1.0000],
#         [ 3.3855,  1.2872,  1.0263,  ...,  3.2100,  0.6000,  6.0000]],
#        device='cuda:0')
# tensor([[ 0.3760,  0.3694,  0.3733,  ...,  3.2400,  0.3600,  4.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  1.0600,  0.7000,  8.0000],
#         [ 2.8272,  2.9050,  3.0155,  ...,  1.0600,  0.6000,  8.0000],
#         ...,
#         [ 0.8355,  0.8786,  0.9074,  ...,  4.7300,  0.8100, 29.0000],
#         [ 3.3619,  3.5000,  3.3347,  ...,  4.4800,  1.0200, 34.0000],
#         [ 3.5000,  3.5000,  0.9849,  ...,  1.0000,  0.6000, 58.0000]],
#        device='cuda:0')
# tensor([[ 1.6066,  0.4204,  0.4051,  ...,  3.2300,  0.3900,  5.0000],
#         [ 3.5000,  1.5457,  1.5611,  ...,  1.0000,  0.7200, 11.0000],
#         [ 2.7795,  2.8041,  2.8777,  ...,  1.0000,  0.6000,  9.0000],
#         ...,
#         [ 0.8608,  0.8906,  0.9405,  ...,  4.7000,  0.7900, 29.0000],
#         [ 3.4423,  3.5000,  1.7195,  ...,  4.4100,  0.9600, 34.0000],
#         [ 2.6620,  3.5000,  3.5000,  ...,  0.9700,  0.6200, 13.0000]],
#        device='cuda:0')
# tensor([[ 0.9097,  1.3862,  3.2021,  ...,  4.5300,  0.7500, 46.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  1.8800,  0.3400,  9.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  4.2500,  0.4700,  8.0000],
#         ...,
#         [ 2.7517,  2.7600,  2.8148,  ...,  2.7700,  0.8100, 36.0000],
#         [ 1.2492,  1.2574,  1.2783,  ...,  2.8500,  0.4900, 16.0000],
#         [ 2.9470,  2.9307,  1.3241,  ...,  3.3100,  0.6400,  4.0000]],
#        device='cuda:0')
# tensor([[ 3.2545,  3.2439,  3.2423,  ...,  4.4700,  0.7200, 46.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  1.8000,  0.3300,  7.0000],
#         [ 1.4702,  1.5513,  1.6504,  ...,  4.2400,  0.4700, 11.0000],
#         ...,
#         [ 1.1855,  1.2398,  1.2775,  ...,  2.7300,  0.7600, 32.0000],
#         [ 1.3328,  1.3562,  1.4199,  ...,  2.7800,  0.4700, 15.0000],
#         [ 0.6801,  0.6833,  0.6891,  ...,  3.2800,  0.6800,  0.0000]],
#        device='cuda:0')
# tensor([[ 1.9520,  2.0774,  2.0609,  ...,  3.8600,  0.3800, 14.0000],
#         [ 0.7023,  0.6404,  0.5718,  ...,  0.1500,  0.4200, 14.0000],
#         [ 0.4349,  0.3773,  0.3518,  ...,  4.7700,  0.3500,  2.0000],
#         ...,
#         [ 1.3829,  1.1858,  1.0264,  ...,  5.2800,  0.6200,  8.0000],
#         [ 1.7246,  1.6398,  1.5610,  ...,  5.4900,  0.4600, 16.0000],
#         [ 1.9842,  1.5668,  1.2857,  ...,  3.2000,  0.5600, 16.0000]],
#        device='cuda:0')
# tensor([[ 1.8355,  1.7070,  1.6300,  ...,  3.7900,  0.3800,  9.0000],
#         [ 0.8686,  0.7565,  0.6709,  ...,  0.0800,  0.4100, 14.0000],
#         [ 0.5424,  0.4037,  0.3870,  ...,  4.7000,  0.3800,  3.0000],
#         ...,
#         [ 1.2292,  1.0565,  0.9320,  ...,  5.2400,  0.6600,  6.0000],
#         [ 1.4441,  1.4233,  1.4008,  ...,  5.4200,  0.4300, 10.0000],
#         [ 0.8616,  0.7788,  0.7318,  ...,  3.2200,  0.5300, 11.0000]],
#        device='cuda:0')
# tensor([[ 1.1608,  1.1283,  1.1120,  ...,  3.3100,  0.8400, 24.0000],
#         [ 3.1920,  3.3399,  3.2029,  ...,  0.2300,  0.6200, 14.0000],
#         [ 1.8548,  2.0531,  2.5019,  ...,  1.6500,  0.3300, 10.0000],
#         ...,
#         [ 0.3590,  0.3496,  0.3583,  ...,  1.5500,  0.3500,  1.0000],
#         [ 1.8570,  2.0086,  1.9961,  ...,  4.6800,  0.4700, 59.0000],
#         [ 2.5102,  2.4842,  1.4309,  ...,  4.1000,  0.4400, 14.0000]],
#        device='cuda:0')
# tensor([[ 1.1073,  1.1342,  1.1124,  ...,  3.2500,  0.7900, 20.0000],
#         [ 2.1550,  2.7551,  2.8933,  ...,  0.2200,  0.5800,  9.0000],
#         [ 3.2283,  1.8870,  1.9978,  ...,  1.6100,  0.3100, 10.0000],
#         ...,
#         [ 0.3963,  0.3800,  0.3967,  ...,  1.5400,  0.3800,  1.0000],
#         [ 1.5979,  1.5477,  1.5318,  ...,  4.7000,  0.3700, 59.0000],
#         [ 2.6290,  2.5862,  2.5563,  ...,  4.0600,  0.4200, 15.0000]],
#        device='cuda:0')
# tensor([[ 3.1288,  3.5000,  3.5000,  ...,  1.9400,  0.7100,  6.0000],
#         [ 0.4463,  0.5226,  0.6491,  ...,  5.5900,  0.4500,  0.0000],
#         [ 0.6354,  0.5440,  0.4831,  ...,  1.5000,  0.3700,  4.0000],
#         ...,
#         [ 0.6290,  0.5825,  0.5477,  ...,  0.4000,  0.5200,  6.0000],
#         [ 1.1840,  1.1538,  1.1650,  ...,  2.5400,  0.5600, 18.0000],
#         [ 0.8001,  0.7529,  0.6871,  ...,  1.9400,  0.5200, 12.0000]],
#        device='cuda:0')
# tensor([[ 1.5972,  1.8234,  2.1525,  ...,  1.9200,  0.7600,  9.0000],
#         [ 0.5348,  0.5133,  0.5252,  ...,  5.5500,  0.5100,  1.0000],
#         [ 0.4091,  0.4381,  0.4516,  ...,  1.4700,  0.4100,  0.0000],
#         ...,
#         [ 0.5857,  0.5840,  0.5605,  ...,  0.3700,  0.5500,  5.0000],
#         [ 1.1994,  1.1986,  1.2127,  ...,  2.5100,  0.5300, 16.0000],
#         [ 3.0258,  0.9695,  0.8667,  ...,  1.8500,  0.5200, 12.0000]],
#        device='cuda:0')
# tensor([[ 2.8137,  2.7909,  2.7190,  ...,  3.3100,  0.3900,  4.0000],
#         [ 0.9736,  0.9740,  1.0267,  ...,  2.8400,  0.4500, 19.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  0.4600,  0.8800, 26.0000],
#         ...,
#         [ 3.5000,  2.1166,  2.0025,  ...,  1.9000,  0.6100, 35.0000],
#         [ 1.4167,  1.3304,  1.3054,  ...,  4.2800,  0.9500, 24.0000],
#         [ 1.8301,  1.9418,  2.0885,  ...,  4.1300,  0.7000, 19.0000]],
#        device='cuda:0')
# tensor([[ 0.4114,  0.4088,  0.4183,  ...,  3.2700,  0.4100,  1.0000],
#         [ 1.0902,  1.1166,  1.1761,  ...,  2.7900,  0.4200, 17.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  0.4200,  0.8200, 26.0000],
#         ...,
#         [ 2.0700,  2.0540,  2.1896,  ...,  1.8800,  0.5600, 34.0000],
#         [ 1.4178,  1.5592,  1.4753,  ...,  4.2100,  0.8900, 26.0000],
#         [ 2.0471,  2.2028,  2.0892,  ...,  4.0700,  0.6300, 17.0000]],
#        device='cuda:0')
# tensor([[ 0.4934,  0.4739,  0.4613,  ...,  0.9800,  0.4400,  6.0000],
#         [ 0.9922,  1.0385,  1.1034,  ...,  2.7100,  0.9100, 31.0000],
#         [ 2.1919,  1.7396,  1.4567,  ...,  0.6000,  0.6200, 18.0000],
#         ...,
#         [ 2.0459,  2.1830,  2.3871,  ...,  1.7000,  0.5500, 32.0000],
#         [ 3.5000,  2.8983,  2.9456,  ...,  0.9800,  0.3400, 15.0000],
#         [ 1.3082,  0.9834,  0.7819,  ...,  2.9100,  0.6500,  4.0000]],
#        device='cuda:0')
# tensor([[ 0.4384,  0.4495,  0.4445,  ...,  0.9900,  0.4300,  4.0000],
#         [ 1.1457,  1.2273,  1.3121,  ...,  2.6700,  0.8500, 30.0000],
#         [ 1.7697,  1.4413,  1.2384,  ...,  0.5400,  0.6000, 13.0000],
#         ...,
#         [ 3.0559,  1.3491,  1.3216,  ...,  1.6900,  0.5600, 29.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  0.9300,  0.3200, 15.0000],
#         [ 0.7058,  0.7551,  1.9921,  ...,  2.8800,  0.7100,  0.0000]],
#        device='cuda:0')
# tensor([[ 0.8446,  0.8703,  0.9780,  ...,  5.6200,  0.8400,  0.0000],
#         [ 0.9290,  0.8735,  0.8404,  ...,  1.9700,  0.8400,  2.0000],
#         [ 0.5909,  0.5588,  0.5196,  ...,  0.4900,  0.4500,  8.0000],
#         ...,
#         [ 1.9484,  1.9201,  1.9029,  ...,  4.7500,  0.6200, 58.0000],
#         [ 0.8079,  0.6951,  0.5783,  ...,  1.6100,  0.3800,  9.0000],
#         [ 1.3379,  1.3708,  1.4054,  ...,  2.7600,  0.9400, 31.0000]],
#        device='cuda:0')
# tensor([[ 0.9443,  1.0272,  1.1458,  ...,  5.6000,  0.9400, 29.0000],
#         [ 1.1791,  1.0668,  0.9701,  ...,  1.9500,  0.8300, 39.0000],
#         [ 0.9559,  0.8498,  0.7648,  ...,  0.4300,  0.4800, 13.0000],
#         ...,
#         [ 1.1839,  1.3447,  1.5965,  ...,  4.6900,  0.7500, 59.0000],
#         [ 3.0755,  3.1302,  0.9591,  ...,  1.5800,  0.3900, 11.0000],
#         [ 1.6181,  1.6831,  1.8106,  ...,  2.6800,  0.8700, 26.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.5000,  ...,  2.4100,  0.3700, 16.0000],
#         [ 0.4893,  0.5373,  0.5227,  ...,  0.1700,  0.4900,  0.0000],
#         [ 1.2367,  1.2294,  1.2203,  ...,  5.0400,  0.8100, 20.0000],
#         ...,
#         [ 1.6335,  1.6604,  1.7175,  ...,  0.1400,  0.8900, 19.0000],
#         [ 1.2839,  1.0850,  0.8783,  ...,  1.7700,  0.4700, 10.0000],
#         [ 2.5316,  2.5136,  2.5086,  ...,  1.6900,  0.3800, 13.0000]],
#        device='cuda:0')
# tensor([[ 1.9629,  1.8411,  1.8985,  ...,  2.3900,  0.3800, 18.0000],
#         [ 0.5747,  0.6051,  0.6249,  ...,  0.1400,  0.5700,  0.0000],
#         [ 1.2836,  1.2935,  1.3223,  ...,  4.9700,  0.7800, 14.0000],
#         ...,
#         [ 1.8996,  1.9832,  2.0876,  ...,  2.1700,  0.8700, 12.0000],
#         [ 1.1954,  0.9505,  0.8190,  ...,  1.7000,  0.4500,  8.0000],
#         [ 1.7293,  1.6807,  1.9420,  ...,  1.6600,  0.3600, 16.0000]],
#        device='cuda:0')
# tensor([[ 2.2133,  2.1763,  2.1655,  ...,  1.8800,  0.5900, 26.0000],
#         [ 0.9652,  0.6968,  0.7370,  ...,  1.0900,  0.7000,  1.0000],
#         [ 3.2741,  3.2956,  1.1411,  ...,  3.6800,  0.7000, 33.0000],
#         ...,
#         [ 1.2099,  1.3665,  1.3951,  ...,  3.7700,  0.9700, 26.0000],
#         [ 1.4445,  1.1535,  0.9972,  ...,  1.4000,  0.8000,  4.0000],
#         [ 3.0086,  2.9176,  1.7669,  ...,  3.6100,  0.6000, 16.0000]],
#        device='cuda:0')
# tensor([[ 2.1344,  2.1356,  1.0910,  ...,  1.8800,  0.5600, 21.0000],
#         [ 0.7561,  0.7610,  0.7551,  ...,  1.0700,  0.7600,  2.0000],
#         [ 3.3157,  3.2900,  3.2917,  ...,  3.6700,  0.6700, 35.0000],
#         ...,
#         [ 1.1277,  1.2210,  1.3489,  ...,  3.7400,  0.9100, 29.0000],
#         [ 0.8287,  0.8577,  2.2895,  ...,  1.3900,  0.8000, 42.0000],
#         [ 2.5598,  2.7311,  2.7061,  ...,  3.5500,  0.5800, 12.0000]],
#        device='cuda:0')
# tensor([[ 3.2543,  3.5000,  3.5000,  ...,  0.9800,  0.3900, 13.0000],
#         [ 0.6521,  0.5808,  0.5651,  ...,  2.1700,  0.4300, 10.0000],
#         [ 0.4565,  0.4247,  0.3924,  ...,  0.1200,  0.3000, 11.0000],
#         ...,
#         [ 3.5000,  2.0063,  1.8401,  ...,  1.1400,  0.7300, 29.0000],
#         [ 0.6167,  0.6176,  0.5903,  ...,  0.2000,  0.5000,  8.0000],
#         [ 0.6237,  0.5944,  0.5797,  ...,  1.8100,  0.4500, 34.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.5000,  ...,  0.9100,  0.3800, 10.0000],
#         [ 0.7256,  0.6712,  0.6187,  ...,  2.1400,  0.4300, 13.0000],
#         [ 0.3482,  0.3402,  0.3366,  ...,  6.6900,  0.3100,  7.0000],
#         ...,
#         [ 1.5569,  1.4849,  1.4991,  ...,  1.0800,  0.6600, 25.0000],
#         [ 0.5157,  0.5135,  0.4813,  ...,  0.1900,  0.4800,  2.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  1.8100,  0.4500, 28.0000]],
#        device='cuda:0')
# tensor([[ 2.2901,  2.0804,  1.9346,  ...,  0.2300,  0.7000, 50.0000],
#         [ 1.5864,  1.5323,  1.5047,  ...,  2.0100,  0.7700, 15.0000],
#         [ 3.5000,  2.8560,  2.6137,  ...,  3.5100,  0.6500, 12.0000],
#         ...,
#         [ 2.1023,  2.0862,  2.0592,  ...,  0.2400,  0.3800, 20.0000],
#         [ 1.0157,  0.8779,  0.7917,  ...,  1.5400,  0.4900, 13.0000],
#         [ 0.9054,  0.8477,  0.8053,  ...,  6.7100,  0.7300,  6.0000]],
#        device='cuda:0')
# tensor([[ 1.6725,  1.5873,  1.5254,  ...,  0.2200,  0.7200, 46.0000],
#         [ 1.6911,  1.6236,  1.5651,  ...,  2.0000,  0.7500, 16.0000],
#         [ 3.5000,  2.7675,  2.5436,  ...,  3.5200,  0.6400, 12.0000],
#         ...,
#         [ 2.0988,  2.1478,  2.1989,  ...,  0.2200,  0.3600, 20.0000],
#         [ 0.6281,  0.5847,  0.5467,  ...,  1.5100,  0.5000,  7.0000],
#         [ 1.0289,  0.9369,  0.8997,  ...,  6.7000,  0.7200,  7.0000]],
#        device='cuda:0')
# tensor([[ 0.7818,  1.1406,  3.5000,  ...,  0.4900,  0.7400, 21.0000],
#         [ 1.5078,  1.4451,  1.3886,  ...,  3.6400,  0.7800, 23.0000],
#         [ 2.0692,  1.9631,  1.8909,  ...,  4.0200,  0.6400, 12.0000],
#         ...,
#         [ 1.1771,  1.0733,  1.0042,  ...,  4.3800,  0.7900,  8.0000],
#         [ 2.9031,  2.8411,  2.7981,  ...,  1.6900,  0.4700,  6.0000],
#         [ 2.0768,  2.0313,  2.0419,  ...,  0.3200,  0.4300, 23.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.2909,  3.2928,  ...,  0.4700,  0.7100, 22.0000],
#         [ 1.3445,  1.3409,  1.3182,  ...,  3.5600,  0.7300, 18.0000],
#         [ 2.1816,  2.0669,  1.9671,  ...,  3.9700,  0.6400, 12.0000],
#         ...,
#         [ 0.9751,  0.8970,  0.8290,  ...,  4.3100,  0.7900,  5.0000],
#         [ 2.8143,  0.6382,  0.5129,  ...,  1.6500,  0.5000,  3.0000],
#         [ 2.0621,  2.0827,  2.0521,  ...,  0.2500,  0.3900, 22.0000]],
#        device='cuda:0')
# tensor([[ 0.8046,  0.7493,  0.8722,  ...,  0.1300,  0.7500,  1.0000],
#         [ 0.5765,  0.5091,  0.4562,  ...,  2.1500,  0.3600, 13.0000],
#         [ 0.8366,  0.7534,  0.6943,  ...,  2.2000,  0.5000, 14.0000],
#         ...,
#         [ 2.1653,  2.1384,  1.1289,  ...,  5.3500,  1.0800, 59.0000],
# ...
#        device='cuda:0')
# tensor([[ 1.6222,  1.5987,  1.5905,  ...,  2.6200,  1.0100, 31.0000],
#         [ 1.2175,  1.1553,  1.1041,  ...,  1.2500,  0.9900,  7.0000],
#         [ 0.4587,  0.4598,  0.4627,  ...,  2.2800,  0.4600,  0.0000],
#         ...,
#         [ 1.3162,  1.3157,  1.3508,  ...,  2.6200,  0.8800, 59.0000],
#         [ 2.3262,  0.5209,  0.4993,  ...,  4.8600,  0.4300,  4.0000],
#         [ 2.2747,  2.2506,  2.2372,  ...,  3.3500,  0.6800, 22.0000]],
#        device='cuda:0')
# tensor([[ 1.6205,  1.6068,  1.6046,  ...,  2.5900,  0.9600, 28.0000],
#         [ 1.5572,  1.4212,  1.3203,  ...,  1.1900,  0.9900, 10.0000],
#         [ 0.5200,  0.4941,  0.5216,  ...,  2.2800,  0.4900,  1.0000],
#         ...,
#         [ 2.1060,  2.3347,  2.6552,  ...,  2.6100,  0.8900, 23.0000],
#         [ 2.0584,  2.0886,  2.1785,  ...,  4.7900,  0.4500,  7.0000],
#         [ 2.3129,  2.3253,  1.2522,  ...,  3.2900,  0.6400, 18.0000]],
#        device='cuda:0')
# tensor([[ 0.7567,  0.7867,  3.1634,  ...,  4.2400,  0.7600,  0.0000],
#         [ 0.8858,  0.7669,  0.7396,  ...,  0.4000,  0.5000, 13.0000],
#         [ 1.0516,  0.9974,  0.9686,  ...,  0.1800,  0.8600,  6.0000],
#         ...,
#         [ 0.4650,  0.4535,  0.4594,  ...,  1.1000,  0.4500,  1.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  2.2500,  0.6300,  7.0000],
#         [ 1.7349,  1.6554,  1.6434,  ...,  1.9800,  0.5900, 14.0000]],
#        device='cuda:0')
# tensor([[ 3.3068,  3.4103,  3.5000,  ...,  4.1800,  0.7800, 35.0000],
#         [ 0.8132,  0.7540,  0.6836,  ...,  0.3500,  0.4900, 11.0000],
#         [ 1.0231,  0.9880,  0.9406,  ...,  0.1500,  0.8900,  4.0000],
#         ...,
#         [ 0.5020,  0.4883,  0.4987,  ...,  1.1600,  0.4900,  4.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  2.2100,  0.6700,  7.0000],
#         [ 1.6106,  1.5900,  1.5880,  ...,  1.9600,  0.5500, 10.0000]],
#        device='cuda:0')
# tensor([[ 2.9705,  3.0129,  3.0710,  ...,  2.2900,  1.0100, 43.0000],
#         [ 2.4429,  2.5039,  2.5934,  ...,  0.8900,  0.2800, 16.0000],
#         [ 1.3155,  1.3378,  1.2071,  ...,  4.3500,  0.6600, 10.0000],
#         ...,
#         [ 1.1142,  1.1427,  1.1874,  ...,  4.2900,  0.5000, 19.0000],
#         [ 2.9515,  3.1756,  3.4095,  ...,  0.6500,  0.3900,  9.0000],
#         [ 2.7203,  0.9637,  0.9426,  ...,  1.7200,  0.7900, 51.0000]],
#        device='cuda:0')
# tensor([[ 1.3146,  2.9845,  2.9897,  ...,  2.2700,  0.9700, 46.0000],
#         [ 2.8305,  3.0024,  3.2059,  ...,  0.8500,  0.2700,  9.0000],
#         [ 1.3045,  1.2874,  1.3100,  ...,  4.3300,  0.6500, 14.0000],
#         ...,
#         [ 1.4639,  3.1012,  3.3928,  ...,  4.2500,  0.4600, 13.0000],
#         [ 1.4739,  2.6272,  2.7086,  ...,  0.6000,  0.3700, 12.0000],
#         [ 3.5000,  2.6798,  2.7874,  ...,  1.7100,  0.8000, 54.0000]],
#        device='cuda:0')
# tensor([[ 3.2965,  3.1375,  3.0024,  ...,  1.0600,  0.8900, 26.0000],
#         [ 2.1366,  1.7099,  1.4131,  ...,  1.1000,  0.6300, 16.0000],
#         [ 1.8986,  2.0499,  2.2369,  ...,  1.7800,  0.6400, 59.0000],
#         ...,
#         [ 1.9973,  1.8442,  1.7165,  ...,  2.0200,  0.3100, 12.0000],
#         [ 2.2661,  2.3413,  2.4273,  ...,  4.1000,  0.5300, 15.0000],
#         [ 1.1119,  1.1479,  1.1603,  ...,  0.5400,  0.3200, 19.0000]],
#        device='cuda:0')
# tensor([[ 2.8604,  2.8123,  1.4822,  ...,  1.0100,  0.8600, 22.0000],
#         [ 2.3830,  1.8178,  1.5070,  ...,  1.0500,  0.6000, 19.0000],
#         [ 1.6553,  1.7374,  1.8317,  ...,  1.7600,  0.6800, 33.0000],
#         ...,
#         [ 2.0517,  1.8911,  1.7631,  ...,  1.9400,  0.3300, 13.0000],
#         [ 2.3657,  2.4464,  2.5561,  ...,  4.0700,  0.5000, 13.0000],
#         [ 1.1746,  1.2162,  1.2690,  ...,  0.4700,  0.3000, 14.0000]],
#        device='cuda:0')
# tensor([[ 3.0153,  3.5000,  3.5000,  ...,  0.5400,  0.4400, 55.0000],
#         [ 3.0579,  3.2410,  3.4873,  ...,  3.4000,  0.5800,  8.0000],
#         [ 1.2968,  1.7839,  3.3019,  ...,  4.0700,  0.7000, 29.0000],
#         ...,
#         [ 3.5000,  3.5000,  3.5000,  ...,  3.8000,  0.4600, 18.0000],
#         [ 2.8481,  2.7937,  1.6549,  ...,  1.2700,  0.5300, 10.0000],
#         [ 0.7196,  0.7440,  0.7637,  ...,  2.8200,  0.5100, 22.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  2.9817,  ...,  0.5300,  0.4600, 59.0000],
#         [ 2.4462,  0.6564,  0.6374,  ...,  3.4000,  0.6100,  3.0000],
#         [ 3.2761,  3.3102,  3.3454,  ...,  4.0700,  0.6900, 24.0000],
#         ...,
#         [ 2.2929,  2.4074,  2.4785,  ...,  3.8000,  0.4400, 16.0000],
#         [ 2.8026,  1.6845,  1.6994,  ...,  1.2500,  0.5300, 10.0000],
#         [ 0.9164,  1.0156,  1.1282,  ...,  2.7900,  0.4900, 18.0000]],
#        device='cuda:0')
# tensor([[ 1.2920,  1.2801,  1.2614,  ...,  3.0700,  0.6800, 21.0000],
#         [ 3.5000,  2.6662,  2.7167,  ...,  3.5000,  0.5300, 18.0000],
#         [ 0.4416,  0.4128,  0.3858,  ...,  1.8900,  0.2900, 11.0000],
#         ...,
#         [ 1.7790,  2.1532,  3.5000,  ...,  2.3800,  0.4800, 22.0000],
#         [ 2.9580,  3.1011,  3.3238,  ...,  3.2500,  0.3300,  8.0000],
#         [ 1.1551,  1.1015,  1.0596,  ...,  0.8100,  0.9400,  8.0000]],
#        device='cuda:0')
# tensor([[ 1.3154,  1.2883,  1.2962,  ...,  3.0200,  0.6500, 22.0000],
#         [ 2.7247,  2.8119,  2.9555,  ...,  3.4800,  0.4900, 13.0000],
#         [ 0.3935,  0.3694,  0.3430,  ...,  1.8600,  0.3000,  6.0000],
#         ...,
#         [ 1.8089,  2.2696,  3.5000,  ...,  2.3800,  0.4500, 25.0000],
#         [ 3.4449,  3.5000,  0.5991,  ...,  3.2200,  0.3500,  4.0000],
#         [ 1.1595,  1.1236,  1.0629,  ...,  0.7500,  0.9700,  8.0000]],
#        device='cuda:0')
# tensor([[ 0.5441,  0.5912,  0.5924,  ...,  3.3700,  0.5400,  0.0000],
#         [ 1.5030,  1.4404,  1.4276,  ...,  0.4000,  0.8800, 38.0000],
#         [ 3.5000,  3.5000,  2.5124,  ...,  1.4600,  0.4800, 22.0000],
#         ...,
#         [ 2.1756,  2.1684,  3.2822,  ...,  1.0500,  0.3700,  9.0000],
#         [ 0.4505,  0.4502,  0.4201,  ...,  2.3800,  0.3700,  8.0000],
#         [ 2.4413,  2.6087,  2.8649,  ...,  1.7800,  0.4700, 23.0000]],
#        device='cuda:0')
# tensor([[ 0.7016,  0.7587,  0.8111,  ...,  3.3700,  0.7000,  0.0000],
#         [ 1.4087,  1.4294,  1.4276,  ...,  0.3800,  0.8400, 33.0000],
#         [ 1.4308,  3.5000,  3.5000,  ...,  1.4200,  0.4300, 25.0000],
#         ...,
#         [ 2.2910,  2.1229,  3.3999,  ...,  0.9800,  0.4000, 10.0000],
#         [ 0.3949,  0.4016,  0.3718,  ...,  2.3700,  0.3700,  2.0000],
#         [ 3.5000,  3.5000,  2.4895,  ...,  1.7300,  0.4300, 25.0000]],
#        device='cuda:0')
# tensor([[ 1.5117,  1.4757,  1.4650,  ...,  4.8100,  0.5800, 25.0000],
#         [ 2.0356,  2.1140,  2.2260,  ...,  2.6200,  0.4300, 16.0000],
#         [ 0.5115,  0.4683,  0.4356,  ...,  3.0200,  0.3300,  8.0000],
#         ...,
#         [ 1.8779,  1.7952,  1.7799,  ...,  2.4100,  0.8500, 29.0000],
#         [ 2.7070,  2.8286,  2.8241,  ...,  3.3400,  0.6000,  9.0000],
#         [ 0.9672,  1.0050,  1.0677,  ...,  2.8200,  0.8300, 52.0000]],
#        device='cuda:0')
# tensor([[ 1.6158,  1.6541,  1.7467,  ...,  4.7800,  0.5000, 18.0000],
#         [ 2.1369,  1.9757,  1.8532,  ...,  2.5100,  0.4000, 11.0000],
#         [ 0.6563,  0.5798,  0.5028,  ...,  2.9100,  0.3700,  6.0000],
#         ...,
#         [ 1.8166,  1.7880,  1.8130,  ...,  2.3600,  0.8000, 27.0000],
#         [ 3.3893,  3.2634,  3.1401,  ...,  3.3000,  0.6100, 13.0000],
#         [ 1.3951,  1.5356,  1.7118,  ...,  2.7900,  0.8600, 47.0000]],
#        device='cuda:0')
# tensor([[ 0.2604,  0.2737,  0.2745,  ...,  0.1400,  0.2600,  0.0000],
#         [ 1.4135,  1.3189,  1.2433,  ...,  2.1400,  1.0300, 10.0000],
#         [ 3.0099,  2.8584,  2.7769,  ...,  0.2100,  0.6300, 18.0000],
#         ...,
#         [ 2.1549,  0.5778,  0.5635,  ...,  3.2100,  0.4400, 11.0000],
#         [ 1.1411,  1.0995,  1.0784,  ...,  0.5000,  1.0000, 26.0000],
#         [ 1.2206,  1.1799,  1.1855,  ...,  2.7400,  0.8100, 24.0000]],
#        device='cuda:0')
# tensor([[ 0.3104,  0.3137,  0.2969,  ...,  6.0000,  0.3000,  2.0000],
#         [ 1.8020,  1.6007,  1.4919,  ...,  2.1100,  1.0200, 11.0000],
#         [ 2.9686,  2.9785,  2.8658,  ...,  0.1300,  0.5900, 19.0000],
#         ...,
#         [ 2.1646,  0.5921,  0.5519,  ...,  3.2300,  0.4300, 11.0000],
#         [ 1.3171,  1.2789,  1.2150,  ...,  0.4800,  0.9600, 28.0000],
#         [ 1.1533,  1.1466,  1.1503,  ...,  2.7400,  0.7700, 20.0000]],
#        device='cuda:0')
# tensor([[ 1.2682,  1.2073,  1.1866,  ...,  3.2800,  0.8100, 25.0000],
#         [ 0.5978,  0.5501,  0.5003,  ...,  1.4800,  0.3600, 10.0000],
#         [ 0.6129,  0.5843,  0.5439,  ...,  4.2300,  0.4300, 11.0000],
#         ...,
#         [ 3.0281,  3.2640,  3.5000,  ...,  0.6900,  0.3900, 11.0000],
#         [ 0.7031,  0.6953,  0.6803,  ...,  2.9700,  0.6800,  2.0000],
#         [ 1.0351,  0.7615,  0.6112,  ...,  0.4200,  0.4900,  4.0000]],
#        device='cuda:0')
# tensor([[ 1.1788,  1.1507,  1.1335,  ...,  3.2200,  0.7600, 21.0000],
#         [ 0.5573,  0.5034,  0.4783,  ...,  1.4000,  0.3500, 11.0000],
#         [ 0.5581,  0.5466,  0.5249,  ...,  4.1800,  0.4200,  8.0000],
#         ...,
#         [ 2.9515,  3.1756,  3.4095,  ...,  0.6500,  0.3900,  9.0000],
#         [ 0.6774,  0.6994,  0.7095,  ...,  2.9600,  0.6600, 24.0000],
#         [ 0.7891,  0.6045,  0.5269,  ...,  0.3800,  0.5300,  2.0000]],
#        device='cuda:0')
# tensor([[ 2.6933,  2.6454,  2.6218,  ...,  1.3000,  0.3100, 15.0000],
#         [ 3.5000,  1.7368,  1.6077,  ...,  0.2300,  1.0100, 29.0000],
#         [ 1.2188,  1.2252,  1.2276,  ...,  5.3800,  0.6400, 15.0000],
#         ...,
#         [ 0.3809,  0.3663,  0.3540,  ...,  0.5000,  0.2900,  6.0000],
#         [ 0.8015,  0.8813,  0.9785,  ...,  3.2200,  0.8000,  0.0000],
#         [ 0.6027,  0.5635,  0.5325,  ...,  4.0000,  0.4900,  5.0000]],
#        device='cuda:0')
# tensor([[ 1.5278,  1.5351,  1.5189,  ...,  1.2900,  0.3000, 10.0000],
#         [ 1.4961,  1.4060,  1.3633,  ...,  0.1600,  0.9500, 26.0000],
#         [ 1.2999,  1.3180,  1.3632,  ...,  5.3100,  0.6400, 11.0000],
#         ...,
#         [ 0.4306,  0.4349,  0.3831,  ...,  0.4800,  0.3000, 11.0000],
#         [ 0.8041,  0.8736,  0.9301,  ...,  3.1500,  0.8000,  0.0000],
#         [ 0.8797,  0.7808,  0.7253,  ...,  3.9300,  0.5000, 11.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.4401,  ...,  0.5300,  0.9600, 17.0000],
#         [ 2.6050,  2.8370,  3.0814,  ...,  1.8200,  0.7200, 15.0000],
#         [ 3.3283,  3.3896,  3.4848,  ...,  1.1200,  0.2700, 35.0000],
#         ...,
#         [ 0.4857,  0.5021,  0.4964,  ...,  2.8000,  0.4900,  0.0000],
#         [ 1.9109,  1.9612,  2.0280,  ...,  0.1200,  0.3600, 15.0000],
#         [ 1.4847,  1.1941,  0.9692,  ...,  3.5200,  0.6200,  6.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.5000,  ...,  0.5200,  0.9400, 19.0000],
#         [ 2.2744,  2.3854,  2.5122,  ...,  1.8200,  0.7200, 16.0000],
#         [ 3.5000,  3.5000,  2.0806,  ...,  1.0700,  0.2300, 33.0000],
#         ...,
#         [ 0.5723,  0.5401,  0.5176,  ...,  2.7400,  0.5200,  2.0000],
#         [ 0.3565,  0.3542,  0.3414,  ...,  4.1400,  0.3200,  5.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  3.5100,  0.6600, 10.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.5000,  ...,  1.8000,  0.3300,  7.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  1.3400,  0.4400, 24.0000],
#         [ 1.8408,  1.9277,  1.9841,  ...,  0.2000,  0.4200, 16.0000],
#         ...,
#         [ 0.7835,  0.7099,  0.6530,  ...,  3.3900,  0.4600, 12.0000],
#         [ 1.0913,  1.2258,  3.0512,  ...,  1.0800,  0.9600, 41.0000],
#         [ 1.7268,  3.5000,  3.5000,  ...,  2.9200,  0.7600, 42.0000]],
#        device='cuda:0')
# tensor([[ 3.5000,  3.5000,  3.5000,  ...,  1.7600,  0.3700,  6.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  1.3000,  0.4100, 20.0000],
#         [ 1.8595,  1.8766,  1.9532,  ...,  0.1500,  0.3900, 19.0000],
#         ...,
#         [ 1.0405,  0.8815,  0.7713,  ...,  3.3100,  0.4700, 13.0000],
#         [ 0.9146,  0.9630,  1.0500,  ...,  1.0400,  0.9100, 45.0000],
#         [ 1.3862,  1.5323,  1.7479,  ...,  2.9100,  0.7700, 44.0000]],
#        device='cuda:0')
# tensor([[ 0.9247,  0.9039,  0.8701,  ...,  0.4300,  0.7200, 49.0000],
#         [ 1.6649,  1.5584,  1.5354,  ...,  5.3400,  0.4300, 10.0000],
#         [ 1.4117,  1.4049,  1.4287,  ...,  4.8300,  0.7600, 15.0000],
#         ...,
#         [ 1.8855,  1.8123,  1.7781,  ...,  1.9300,  0.4300, 50.0000],
#         [ 0.8201,  0.7444,  0.7427,  ...,  2.8800,  0.5900, 11.0000],
#         [ 0.5729,  0.5012,  0.4754,  ...,  1.0900,  0.3700, 12.0000]],
#        device='cuda:0')
# tensor([[ 0.9971,  0.9387,  0.9293,  ...,  0.3900,  0.7000, 52.0000],
#         [ 1.8293,  1.9799,  1.8936,  ...,  5.3200,  0.4800, 15.0000],
#         [ 1.5222,  1.4902,  1.4699,  ...,  4.7400,  0.7300, 17.0000],
#         ...,
#         [ 1.7898,  1.7703,  1.7368,  ...,  1.9300,  0.4400, 48.0000],
#         [ 0.6595,  0.6367,  0.6277,  ...,  2.8800,  0.6000,  4.0000],
#         [ 0.5429,  0.5176,  0.4763,  ...,  1.0500,  0.3700,  6.0000]],
#        device='cuda:0')
# tensor([[ 0.6651,  0.6569,  0.6624,  ...,  0.8700,  0.6600,  1.0000],
#         [ 0.4830,  0.4431,  0.4310,  ...,  1.8000,  0.3700,  7.0000],
#         [ 3.5000,  3.5000,  3.5000,  ...,  2.9700,  0.5200, 51.0000],
#         ...,
#         [ 0.7334,  0.7432,  3.1194,  ...,  2.4400,  0.7300,  0.0000],
#         [ 0.6802,  0.6094,  0.5552,  ...,  1.8200,  0.4100, 11.0000],
#         [ 0.4361,  0.3625,  0.3429,  ...,  0.9000,  0.3400,  2.0000]],
#        device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-80778db8b023> in <module>()
#       5         calculate_loss()
#       6     policy.update(replay_buffer, 500, batch_size, gamma,
# ----> 7                   polyak, policy_noise, noise_clip, policy_delay, 1)
#
# /home/cmq/ljn/RL/turtlebot3/src/dqn-navigation/turtlebot3_machine_learning/turtlebot3_td3/TD3/TD3.py in update(self, replay_buffer, n_iter, batch_size, gamma, polyak, policy_noise, noise_clip, policy_delay, sample_mode)
#     147             next_state = torch.FloatTensor(next_state).to(device)
#     148             print(state)
# --> 149             print(next_state)
#     150             done = torch.FloatTensor(done).reshape((batch_size,1)).to(device)
#     151             # Select next action according to target policy:
#
# /home/cmq/anaconda2/lib/python2.7/site-packages/torch/tensor.pyc in __repr__(self)
#     131         else:
#     132             if hasattr(sys.stdout, 'encoding'):
# --> 133                 return torch._tensor_str._str(self).encode(
#     134                     sys.stdout.encoding or 'UTF-8', 'replace')
#     135             else:
#
# /home/cmq/anaconda2/lib/python2.7/site-packages/torch/_tensor_str.pyc in _str(self)
#     309                 tensor_str = _tensor_str(self.to_dense(), indent)
#     310             else:
# --> 311                 tensor_str = _tensor_str(self, indent)
#     312
#     313     if self.layout != torch.strided:
#
# /home/cmq/anaconda2/lib/python2.7/site-packages/torch/_tensor_str.pyc in _tensor_str(self, indent)
#     207     if self.dtype is torch.float16 or self.dtype is torch.bfloat16:
#     208         self = self.float()
# --> 209     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     210     return _tensor_str_with_formatter(self, indent, formatter, summarize)
#     211
#
# /home/cmq/anaconda2/lib/python2.7/site-packages/torch/_tensor_str.pyc in __init__(self, tensor)
#     124                 else:
#     125                     for value in nonzero_finite_vals:
# --> 126                         value_str = ('{{:.{}f}}').format(PRINT_OPTS.precision).format(value)
#     127                         self.max_width = max(self.max_width, len(value_str))
#     128
#
# /home/cmq/anaconda2/lib/python2.7/site-packages/torch/tensor.pyc in __format__(self, format_spec)
#     375     def __format__(self, format_spec):
#     376         if self.dim() == 0:
# --> 377             return self.item().__format__(format_spec)
#     378         return object.__format__(self, format_spec)
#     379
#
# KeyboardInterrupt:
